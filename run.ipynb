# %%
import geonamescache
import re
import unidecode
import pandas as pd
from geonamescache.mappers import country
mapper = country(from_key='iso', to_key='name')

gc = geonamescache.GeonamesCache()
# Gets all countries
countries = tuple(sorted(gc.get_countries_by_names().keys()))
assert len(countries) == 252
# Gets all city names (country does NOT matter, just the name).
cities = tuple(sorted(set([unidecode.unidecode(v['name']) for (k, v) in gc.get_cities().items()])))
us_states = tuple(sorted(gc.get_us_states_by_names()))
us_counties = tuple(sorted(set([county['name'].split()[0].strip() for county in gc.get_us_counties()])))
assert 'Louisiana' not in cities
assert 'Antigua' not in cities and 'Antigua Guatemala' in cities
assert 'Sussex' not in cities and 'Sussex' in us_counties
assert 'Louisiana' in us_states
assert len(cities) == 23022

# %%
# Creating an empty Dataframe with column names only
df = pd.DataFrame(columns=['headline', 'city', 'country'])
with open("data/headlines.txt") as f:
    for line in f.read().splitlines():
        matches = []
        # Each headline contains the city, never the country alone. So loop over the cities.
        # However we could have an US state or a county. Ignore them for now.
        for city in cities:
            if re.search(f"\\b{city}\\b", line, re.IGNORECASE):
                matches.append(city)
        # In 'Could Zika Reach New York City?', we will find 'New York City' AND 'York'
        if matches:
            # Consider the longest match
            match = max(matches, key=len)
            gc_cities = gc.get_cities_by_name(match)
            if not gc_cities:
                print(f"NO match for city name '{match}'.")
            elif len(gc_cities) > 1:
                print(f"Too many entries found for city name '{match}'.")
            else:
                gc_city = list(gc_cities[0].values())[0]
                df = df.append({'headline': line, 'city': city, 'country': mapper(gc_city['countrycode'])}, ignore_index=True)
        else:
            # Should we extend the search to US states/counties
            print(f"No one single match found in headline '{line}'.")
df.to_csv(index=False, 'output.csv', encoding='utf-8')
print("Finished!")
# Out:
# Too many entries found for city name 'Dallas'.
# Too many entries found for city name 'Trinidad'.
# NO match for city name 'Geneve'.
# NO match for city name 'Sao Paulo'.
# Too many entries found for city name 'Brownsville'.
# Too many entries found for city name 'San Juan'.
# No one single match found in headline 'Louisiana Zika cases up to 26'.
# No one single match found in headline 'Zika infects pregnant woman in Cebu'.
# Too many entries found for city name 'Flint'.
# Too many entries found for city name 'London'.
# Too many entries found for city name 'Boston'.
# Too many entries found for city name 'Paris'.
# Too many entries found for city name 'San Diego'.
# Too many entries found for city name 'San Francisco'.
# Too many entries found for city name 'Santa Rosa'.
# Too many entries found for city name 'Cleveland'.
# Too many entries found for city name 'Austin'.
# Too many entries found for city name 'Lima'.
# NO match for city name 'Bogota'.
# No one single match found in headline 'Spanish Flu Sighted in Antigua'.
# Too many entries found for city name 'Vancouver'.
# Too many entries found for city name 'Madison'.
# NO match for city name 'Brasilia'.
# Too many entries found for city name 'Jacksonville'.
# Too many entries found for city name 'Sydney'.
# No one single match found in headline 'Zika case reported in Oton'.
# No one single match found in headline 'Hillsborough uses innovative trap against Zika 20 minutes ago'.
# Too many entries found for city name 'Campinas'.
# Too many entries found for city name 'Rome'.
# NO match for city name 'Quebec'.
# Too many entries found for city name 'Rochester'.
# NO match for city name 'Cucuta'.
# No one single match found in headline 'Maka City Experiences Influenza Outbreak'.
# Too many entries found for city name 'San Antonio'.
# Too many entries found for city name 'Melbourne'.
# Too many entries found for city name 'Columbus'.
# Too many entries found for city name 'Hollywood'.
# Too many entries found for city name 'Hamilton'.
# Too many entries found for city name 'Hyderabad'.
# Too many entries found for city name 'Birmingham'.
# NO match for city name 'Cancun'.
# NO match for city name 'Cancun'.
# Too many entries found for city name 'Barcelona'.
# Too many entries found for city name 'Santa Barbara'.
# Too many entries found for city name 'Laredo'.
# Too many entries found for city name 'Springfield'.
# Too many entries found for city name 'Westchester'.
# Too many entries found for city name 'Colombo'.
# Too many entries found for city name 'Louisville'.
# Too many entries found for city name 'Florence'.
# Too many entries found for city name 'Huntsville'.
# Too many entries found for city name 'Athens'.
# No one single match found in headline 'West Nile Virus Outbreak in Saint Johns'.
# Too many entries found for city name 'Belmont'.
# Too many entries found for city name 'Sacramento'.
# Too many entries found for city name 'Veracruz'.
# Too many entries found for city name 'Kingston'.
# Too many entries found for city name 'Gainesville'.
# NO match for city name 'Arhus'.
# NO match for city name 'Niteroi'.
# Too many entries found for city name 'Manhattan'.
# Too many entries found for city name 'Syracuse'.
# Too many entries found for city name 'Fresno'.
# Too many entries found for city name 'Kansas City'.
# Too many entries found for city name 'Cambridge'.
# Too many entries found for city name 'Toledo'.
# Too many entries found for city name 'Lafayette'.
# Too many entries found for city name 'San Benito'.
# NO match for city name 'Joao Pessoa'.
# Too many entries found for city name 'Chatham'.
# Too many entries found for city name 'Naples'.
# Too many entries found for city name 'Oxford'.
# Too many entries found for city name 'Windsor'.
# Too many entries found for city name 'San Jose'.
# Too many entries found for city name 'Farmington'.
# Too many entries found for city name 'Albany'.
# Too many entries found for city name 'Madera'.
# Too many entries found for city name 'Lagos'.
# Too many entries found for city name 'Birmingham'.
# No one single match found in headline 'Malaria Exposure in Sussex'.
# Too many entries found for city name 'Newark'.
# Too many entries found for city name 'Florida'.
# No one single match found in headline 'Greenwich Establishes Zika Task Force'.
# Too many entries found for city name 'Murcia'.
# Too many entries found for city name 'Margate'.
# No one single match found in headline 'Will West Nile Virus vaccine help Parsons?'.
# Too many entries found for city name 'Vienna'.
# Too many entries found for city name 'Orange'.
# Too many entries found for city name 'Richmond'.
# Too many entries found for city name 'Medina'.
# NO match for city name 'Hit'.
# Too many entries found for city name 'Hollywood'.
# Too many entries found for city name 'Durham'.
# Too many entries found for city name 'Albany'.
# NO match for city name 'Yaounde'.
# Too many entries found for city name 'Harlingen'.
# Too many entries found for city name 'Rotterdam'.
# Too many entries found for city name 'Arlington'.
# Too many entries found for city name 'Dublin'.
# Too many entries found for city name 'Salem'.
# No one single match found in headline 'Zika case reported in Los Fresnos'.
# NO match for city name 'Camacari'.
# Too many entries found for city name 'Palm Springs'.
# Too many entries found for city name 'Halifax'.
# Too many entries found for city name 'Rochester'.
# Too many entries found for city name 'Wellington'.
# Too many entries found for city name 'Ottawa'.
# Too many entries found for city name 'Bloomington'.
# No one single match found in headline 'More people in Boucau are infected with HIV every year'.
# Too many entries found for city name 'Madrid'.
# Too many entries found for city name 'Madrid'.
# Too many entries found for city name 'Santiago'.
# Too many entries found for city name 'Ennis'.
# Too many entries found for city name 'Richmond'.
# No one single match found in headline 'Bronchitis Outbreak in Manhasset'.
# Too many entries found for city name 'Lakewood'.
# Too many entries found for city name 'Brighton'.
# Too many entries found for city name 'Bridgeport'.
# NO match for city name 'Come'.
# NO match for city name 'Surat'.
# No one single match found in headline 'Rumors about Influenza Spreading in Dobbs Ferry have been Refuted'.
# Too many entries found for city name 'Bedford'.
# Too many entries found for city name 'Milford'.
# Too many entries found for city name 'Monroe'.
# Too many entries found for city name 'Saginaw'.
# Too many entries found for city name 'Saint Charles'.
# Too many entries found for city name 'Newcastle'.
# Too many entries found for city name 'Erie'.
# No one single match found in headline 'More people in Huron are infected with Dengue every year'.
# Too many entries found for city name 'Greenville'.
# NO match for city name 'Montreal'.
# Too many entries found for city name 'Stamford'.
# Too many entries found for city name 'Huntington'.
# Too many entries found for city name 'Bristol'.
# Too many entries found for city name 'Stillwater'.
# Too many entries found for city name 'Imperial'.
# No one single match found in headline 'Will Tuberculosis vaccine help Cherry Creek?'.
# No one single match found in headline 'Gympie Patient in Critical Condition after Contracting Chlamydia'.
# Too many entries found for city name 'Norwalk'.
# Too many entries found for city name 'Orange'.
# Too many entries found for city name 'La Paz'.
# Too many entries found for city name 'Carrollton'.
# Too many entries found for city name 'Lansing'.
# Too many entries found for city name 'Melbourne'.
# Too many entries found for city name 'La Libertad'.
# Too many entries found for city name 'Kent'.
# Too many entries found for city name 'Santa Elena'.
# Too many entries found for city name 'Plainfield'.
# Too many entries found for city name 'Carlsbad'.
# Too many entries found for city name 'Germantown'.
# Too many entries found for city name 'Fairfield'.
# Too many entries found for city name 'Santa Fe'.
# Too many entries found for city name 'Alexandria'.
# Too many entries found for city name 'Alhambra'.
# Too many entries found for city name 'Damascus'.
# Too many entries found for city name 'Hammond'.
# Too many entries found for city name 'Quezon'.
# Too many entries found for city name 'Greenville'.
# Too many entries found for city name 'San Mateo'.
# Too many entries found for city name 'Fremont'.
# Too many entries found for city name 'Monroe'.
# NO match for city name 'Ribeirao Preto'.
# No one single match found in headline 'Martinsville tests new cure for Measles'.
# No one single match found in headline 'More Patients in Magnolia are Getting Diagnosed with Malaria'.
# Too many entries found for city name 'Durango'.
# Too many entries found for city name 'Gladstone'.
# Too many entries found for city name 'London'.
# NO match for city name 'Custodia'.
# No one single match found in headline 'Rumors about Syphilis spreading in Penal have been refuted'.
# Too many entries found for city name 'Madrid'.
# Too many entries found for city name 'Barcelona'.
# Too many entries found for city name 'Madrid'.
# Too many entries found for city name 'Barcelona'.
# Too many entries found for city name 'Redmond'.
# Too many entries found for city name 'Concord'.
# No one single match found in headline 'Fort Belvoir tests new cure for Hepatitis C'.
# No one single match found in headline 'More people in Oak Brook are infected with Respiratory Syncytial Virus every year'.
# Too many entries found for city name 'Darien'.
# Too many entries found for city name 'Fairfield'.
# Too many entries found for city name 'Princeton'.
# NO match for city name 'San Luis Potosi'.
# Too many entries found for city name 'Palm Springs'.
# No one single match found in headline 'Longwood volunteers spreading Zika awareness'.
# Too many entries found for city name 'Leesburg'.
# NO match for city name 'Cantu'.
# No one single match found in headline 'Zika symptoms spotted in Quixere'.
# NO match for city name 'Kihei'.
# Too many entries found for city name 'Colombo'.
# NO match for city name 'Come'.
# NO match for city name 'Medellin'.
# Too many entries found for city name 'Monroe'.
# Too many entries found for city name 'Moscow'.
# NO match for city name 'Ciudad Acuna'.
# Too many entries found for city name 'Henderson'.
# Too many entries found for city name 'Canton'.
# NO match for city name 'Kedougou'.
# Too many entries found for city name 'Norwalk'.
# Too many entries found for city name 'Medford'.
# Too many entries found for city name 'San Jose'.
# Too many entries found for city name 'Duluth'.
# No one single match found in headline 'Measles Hits Davos'.
# Too many entries found for city name 'Norfolk'.
# Too many entries found for city name 'Fayetteville'.
# Too many entries found for city name 'Cambridge'.
# Too many entries found for city name 'Morristown'.
# Too many entries found for city name 'Corona'.
# Too many entries found for city name 'Danville'.
# Too many entries found for city name 'Aurora'.
# Too many entries found for city name 'Manchester'.
# No one single match found in headline 'Schools in Coamo Closed Due to Rhinovirus Outbreak'.
# No one single match found in headline 'Zika arrives in Dangriga'.
# Too many entries found for city name 'Kensington'.
# No one single match found in headline 'More Patients in Maynard are Getting Diagnosed with Syphilis'.
# Too many entries found for city name 'Riverside'.
# Too many entries found for city name 'Monroe'.
# Too many entries found for city name 'Trenton'.
# Too many entries found for city name 'Hampton'.
# NO match for city name 'Sao Jose'.
# Too many entries found for city name 'Stratford'.
# Too many entries found for city name 'Bethlehem'.
# Too many entries found for city name 'Suzhou'.
# No one single match found in headline 'Zika case reported in Antioquia'.
# No one single match found in headline 'Chikungunya has not Left Pismo Beach'.
# No one single match found in headline 'Zika spreads to La Joya'.
# Too many entries found for city name 'Bedford'.
# Too many entries found for city name 'Easton'.
# Too many entries found for city name 'Milton'.
# Too many entries found for city name 'Sevilla'.
# Too many entries found for city name 'Clovis'.
# Too many entries found for city name 'Bella Vista'.
# 'headline,city,country\nZika Outbreak Hits Miami,maalot Tarshiha,USA\nCould Zika Reach New York City?,maalot Tarshiha,USA\nFirst Case of Zika in Miami Beach,maalot Tarshiha,USA\n"Mystery Virus Spreads in Recife, Brazil",maalot Tarshiha,\nZika Concerns are Spreading in Houston,maalot Tarshiha,USA\nThe CDC in Atlanta is Growing Worried,maalot Tarshiha,USA\nMosquito control efforts in St. Louis take new tactics with Zika threat,maalot Tarshiha,USA\n"Flu outbreak in Galveston, Texas",maalot Tarshiha,USA\nZika alert – Manila now threatened,maalot Tarshiha,\nZika afflicts 7 in Iloilo City,maalot Tarshiha,\nNew Los Angeles Hairstyle goes Viral,maalot Tarshiha,USA\nOrlando volunteers aid Zika research,maalot Tarshiha,USA\nChicago\'s First Zika Case Confirmed,maalot Tarshiha,USA\nTampa Bay Area Zika Case Count Climbs,maalot Tarshiha,USA\nBaltimore plans for Zika virus,maalot Tarshiha,USA\nZika cases in Vietnam\'s Ho Chi Minh City surge,maalot Tarshiha,\nPhiladelphia experts track pandemic,maalot Tarshiha,USA\nThailand-